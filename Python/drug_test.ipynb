# %% [markdown]
# <a href="https://colab.research.google.com/github/gr8rithic/Drug_Test_ML/blob/master/Drug_test_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading https://files.pythonhosted.org/packages/e5/c9/a909331598965376ba15a9e5dbe02b5a007172c0726e6cd56424f558b236/chembl-webresource-client-0.10.4.tar.gz (51kB)
#      |████████████████████████████████| 61kB 7.3MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (2.23.0)
# Collecting requests-cache>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/1d/a1/3062a791c433212c98a7dd2e510913bccd09e8d216d7da273f44736ae7c7/requests_cache-0.6.4-py2.py3-none-any.whl
# Requirement already satisfied: easydict in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Collecting url-normalize>=1.4
#   Downloading https://files.pythonhosted.org/packages/65/1c/6c6f408be78692fc850006a2b6dea37c2b8592892534e09996e401efc74b/url_normalize-1.4.3-py2.py3-none-any.whl
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.7/dist-packages (from requests-cache>=0.6.0->chembl_webresource_client) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from url-normalize>=1.4->requests-cache>=0.6.0->chembl_webresource_client) (1.15.0)
# Building wheels for collected packages: chembl-webresource-client
#   Building wheel for chembl-webresource-client (setup.py) ... done
#   Created wheel for chembl-webresource-client: filename=chembl_webresource_client-0.10.4-cp37-none-any.whl size=55663 sha256=6a7186e44c53392d348d20ba201b0d644d6cd077a4480964ecad7d524d2ecaa2
#   Stored in directory: /root/.cache/pip/wheels/98/4c/16/bdb2ef9c937173e56b04d71fc1a6f98f0ff24992ae2e35daf3
# Successfully built chembl-webresource-client
# Installing collected packages: url-normalize, requests-cache, chembl-webresource-client
# Successfully installed chembl-webresource-client-0.10.4 requests-cache-0.6.4 url-normalize-1.4.3

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
search = target.search('coronavirus')
df = pd.DataFrame.from_dict(search)
df
# Out:
#                                     cross_references  ...   tax_id
# 0                                                 []  ...    11119
# 1                                                 []  ...   227859
# 2                                                 []  ...    12663
# 3                                                 []  ...    11137
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...  ...   227859
# 5                                                 []  ...  1335626
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...  ...   227859
# 7                                                 []  ...  2697049
#
# [8 rows x 9 columns]

# %%
selected_target = df.	target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3927'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id = selected_target).filter(standard_type ="IC50")
res
# Out:
# [{'activity_comment': None, 'activity_id': 1480935, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL829584', 'assay_description': 'In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease)', 'assay_type': 'B', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000357', 'bao_label': 'single protein format', 'canonical_smiles': 'Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21', 'data_validity_comment': None, 'data_validity_description': None, 'document_chembl_id': 'CHEMBL1139624', 'document_journal': 'Bioorg. Med. Chem. Lett.', 'document_year': 2005, 'ligand_efficiency': {'bei': '18.28', 'le': '0.33', 'lle': '3.25', 'sei': '5.90'}, 'molecule_chembl_id': 'CHEMBL187579', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL187579', 'pchembl_value': '5.14', 'potential_duplicate': False, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 384103, 'relation': '=', 'src_id': 1, 'standard_flag': True, 'standard_relation': '=', 'standard_text_value': None, 'standard_type': 'IC50', 'standard_units': 'nM', 'standard_upper_value': None, 'standard_value': '7200.0', 'target_chembl_id': 'CHEMBL3927', 'target_organism': 'SARS coronavirus', 'target_pref_name': 'SARS coronavirus 3C-like proteinase', 'target_tax_id': '227859', 'text_value': None, 'toid': None, 'type': 'IC50', 'units': 'uM', 'uo_units': 'UO_0000065', 'upper_value': None, 'value': '7.2'}, {'activity_comment': None, 'activity_id': 1480936, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL829584', 'assay_description': 'In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease)', 'assay_type': 'B', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000357', 'bao_label': 'single protein format', 'canonical_smiles': 'O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21', 'data_validity_comment': None, 'data_validity_description': None, 'document_chembl_id': 'CHEMBL1139624', 'document_journal': 'Bioorg. Med. Chem. Lett.', 'document_year': 2005, 'ligand_efficiency': {'bei': '12.10', 'le': '0.33', 'lle': '1.22', 'sei': '13.45'}, 'molecule_chembl_id': 'CHEMBL188487', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL188487', 'pchembl_value': '5.03', 'potential_duplicate': False, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 383984, 'relation': '=', 'src_id': 1, 'standard_flag': True, 'standard_relation': '=', 'standard_text_value': None, 'standard_type': 'IC50', 'standard_units': 'nM', 'standard_upper_value': None, 'standard_value': '9400.0', 'target_chembl_id': 'CHEMBL3927', 'target_organism': 'SARS coronavirus', 'target_pref_name': 'SARS coronavirus 3C-like proteinase', 'target_tax_id': '227859', 'text_value': None, 'toid': None, 'type': 'IC50', 'units': 'uM', 'uo_units': 'UO_0000065', 'upper_value': None, 'value': '9.4'}, {'activity_comment': None, 'activity_id': 1481061, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL830868', 'assay_description': 'In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease) at 20 uM', 'assay_type': 'B', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000357', 'bao_label': 'single protein format', 'canonical_smiles': 'O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21', 'data_validity_comment': None, 'data_validity_description': None, 'document_chembl_id': 'CHEMBL1139624', 'document_journal': 'Bioorg. Med. Chem. Lett.', 'document_year': 2005, 'ligand_efficiency': {'bei': '11.56', 'le': '0.29', 'lle': '2.21', 'sei': '8.72'}, 'molecule_chembl_id': 'CHEMBL185698', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL185698', 'pchembl_value': '4.87', 'potential_duplicate': False, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 384106, 'relation': '=', 'src ...

# %%
df2 = pd.DataFrame.from_dict(res)
df2
# Out:
#     activity_comment  activity_id  ... upper_value  value
# 0               None      1480935  ...        None    7.2
# 1               None      1480936  ...        None    9.4
# 2               None      1481061  ...        None   13.5
# 3               None      1481065  ...        None  13.11
# 4               None      1481066  ...        None    2.0
# ..               ...          ...  ...         ...    ...
# 128             None     12041507  ...        None   10.6
# 129             None     12041508  ...        None   10.1
# 130             None     12041509  ...        None   11.5
# 131             None     12041510  ...        None   10.7
# 132             None     12041511  ...        None   78.9
#
# [133 rows x 45 columns]

# %%
df2.dropna()
df2
# Out:
#     activity_comment  activity_id  ... upper_value  value
# 0               None      1480935  ...        None    7.2
# 1               None      1480936  ...        None    9.4
# 2               None      1481061  ...        None   13.5
# 3               None      1481065  ...        None  13.11
# 4               None      1481066  ...        None    2.0
# ..               ...          ...  ...         ...    ...
# 128             None     12041507  ...        None   10.6
# 129             None     12041508  ...        None   10.1
# 130             None     12041509  ...        None   11.5
# 131             None     12041510  ...        None   10.7
# 132             None     12041511  ...        None   78.9
#
# [133 rows x 45 columns]

# %%
bio_activity = []
for i in df2.standard_value:
  if float(i) > 10000:
    bio_activity.append("active")
  elif float(i) < 1000:
    bio_activity.append("inactive")
  else:
    bio_activity.append("intermediate")

# %%
bio_active_status = pd.Series(bio_activity, name = "class")
df3 = pd.concat([df2,bio_active_status],axis=1)

# %%
df3
# Out:
#     activity_comment  activity_id  ...  value         class
# 0               None      1480935  ...    7.2  intermediate
# 1               None      1480936  ...    9.4  intermediate
# 2               None      1481061  ...   13.5        active
# 3               None      1481065  ...  13.11        active
# 4               None      1481066  ...    2.0  intermediate
# ..               ...          ...  ...    ...           ...
# 128             None     12041507  ...   10.6        active
# 129             None     12041508  ...   10.1        active
# 130             None     12041509  ...   11.5        active
# 131             None     12041510  ...   10.7        active
# 132             None     12041511  ...   78.9        active
#
# [133 rows x 46 columns]

# %%
ls = ['molecule_chembl_id','canonical_smiles','standard_value','class']
df3 = df3[ls]
df3
# Out:
#     molecule_chembl_id  ...         class
# 0         CHEMBL187579  ...  intermediate
# 1         CHEMBL188487  ...  intermediate
# 2         CHEMBL185698  ...        active
# 3         CHEMBL426082  ...        active
# 4         CHEMBL187717  ...  intermediate
# ..                 ...  ...           ...
# 128      CHEMBL2146517  ...        active
# 129       CHEMBL187460  ...        active
# 130       CHEMBL363535  ...        active
# 131       CHEMBL227075  ...        active
# 132        CHEMBL45830  ...        active
#
# [133 rows x 4 columns]

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2021-06-10 04:50:12--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   184MB/s    in 0.4s
#
# 2021-06-10 04:50:12 (184 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-1.3.0-py37_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.1.1-0
#   certifi            pkgs/main/linux-64::certifi-2019.11.28-py37_0
#   cffi               pkgs/main/linux-64::cffi-1.14.0-py37h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py37_1003
#   conda              pkgs/main/linux-64::conda-4.8.2-py37_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py37h7b6447c_0
#   cryptography       pkgs/main/linux-64::cryptography-2.8-py37h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py37_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1d-h7b6447c_4
#   pip                pkgs/main/linux-64::pip-20.0.2-py37_1
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h7b6447c_0
#   pycparser          pkgs/main/linux-64::pycparser-2.19-py37_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-py37_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py37_0
#   python             pkgs/main/linux-64::python-3.7.6-h0371630_2
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py37_1
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py37h7b6447c_0
#   setuptools         pkgs/main/linux-64::setuptools-45.2.0-py37_0
#   six                pkgs/main/linux-64::six-1.14.0-py37_0
#   sqlite             pkgs/main/linux-64::sqlite-3.31.1-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.42.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.25.8-py37_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py37_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     bzip2-1.0.8                |       h7b6447c_0          78 KB
#     ca-certificates-2021.5.25  |       h06a4308_1         112 KB
#     cairo-1.16.0               |       hf32fb01_1         1.0 MB
#     certifi-2021.5.30          |   py37h06a4308_0         139 KB
#     conda-4.10.1               |   py37h06a4308_1         2.9 MB
#     fontconfig-2.13.1          |       h6c09931_0         250 KB
#     freetype-2.10.4            |       h5ab3b9f_0         596 KB
#     glib-2.68.2                |       h36276a3_0         3.0 MB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     intel-openmp-2021.2.0      |     h06a4308_610         1.3 MB
#     jpeg-9b                    |       h024ee3a_2         214 KB
#     lcms2-2.12                 |       h3be6417_0         312 KB
#     libboost-1.73.0            |      h3ff78a5_11        13.9 MB
#     libffi-3.3                 |       he6710b0_2          50 KB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libtiff-4.2.0              |       h85742a9_0         502 KB
#     libuuid-1.0.3              |       h1bed415_2          15 KB
#     libwebp-base-1.2.0         |       h27cfd23_0         437 KB
#     libxcb-1.14                |       h7b6447c_0         505 KB
#     libxml2-2.9.10             |       hb55368b_3         1.2 MB
#     lz4-c-1.9.3                |       h2531618_0         186 KB
#     mkl-2021.2.0               |     h06a4308_296       144.3 MB
#     mkl-service-2.3.0          |   py37h27cfd23_1          55 KB
#     mkl_fft-1.3.0              |   py37h42c9631_2         170 KB
#     mkl_random-1.2.1           |   py37ha9443f7_2         287 KB
#     numpy-1.20.2               |   py37h2d18471_0          23 KB
#     numpy-base-1.20.2          |   py37hfae3a4d_0         4.5 MB
#     olefile-0.46               |           py37_0          50 KB
#     openssl-1.1.1k             |       h27cfd23_0         2.5 MB
#     pandas-1.2.4               |   py37h2531618_0         8.5 MB
#     pcre-8.44                  |       he6710b0_0         212 KB
#     pillow-8.2.0               |   py37he98fc37_0         622 KB
#     pixman-0.40.0              |       h7b6447c_0         370 KB
#     py-boost-1.73.0            |  py37ha9443f7_11         204 KB
#     python-dateutil-2.8.1      |     pyhd3eb1b0_0         221 KB
#     pytz-2021.1                |     pyhd3eb1b0_0         181 KB
#     rdkit-2020.09.1.0          |   py37hd50e099_1        25.8 MB  rdkit
#     xz-5.2.5                   |       h7b6447c_0         341 KB
#     zstd-1.4.9                 |       haebb681_0         480 KB
#     ------------------------------------------------------------
#                                            Total:       226.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h7b6447c_0
#   cairo              pkgs/main/linux-64::cairo-1.16.0-hf32fb01_1
#   fontconfig         pkgs/main/linux-64::fontconfig-2.13.1-h6c09931_0
#   freetype           pkgs/main/linux-64::freetype-2.10.4-h5ab3b9f_0
#   glib               pkgs/main/linux-64::glib-2.68.2-h36276a3_0
#   icu                pkgs/main/linux-64::icu-58.2-he6710b0_3
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2021.2.0-h06a4308_610
#   jpeg               pkgs/main/linux-64::jpeg-9b-h024ee3a_2
#   lcms2              pkgs/main/linux-64::lcms2-2.12-h3be6417_0
#   libboost           pkgs/main/linux-64::libboost-1.73.0-h3ff78a5_11
#   libpng             pkgs/main/linux-64::libpng-1.6.37-hbc83047_0
#   libtiff            pkgs/main/linux-64::libtiff-4.2.0-h85742a9_0
#   libuuid            pkgs/main/linux-64::libuuid-1.0.3-h1bed415_2
#   libwebp-base       pkgs/main/linux-64::libwebp-base-1.2.0-h27cfd23_0
#   libxcb             pkgs/main/linux-64::libxcb-1.14-h7b6447c_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.10-hb55368b_3
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.3-h2531618_0
#   mkl                pkgs/main/linux-64::mkl-2021.2.0-h06a4308_296
#   mkl-service        pkgs/main/linux-64::mkl-service-2.3.0-py37h27cfd23_1
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.0-py37h42c9631_2
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.1-py37ha9443f7_2
#   numpy              pkgs/main/linux-64::numpy-1.20.2-py37h2d18471_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.20.2-py37hfae3a4d_0
#   olefile            pkgs/main/linux-64::olefile-0.46-py37_0
#   pandas             pkgs/main/linux-64::pandas-1.2.4-py37h2531618_0
#   pcre               pkgs/main/linux-64::pcre-8.44-he6710b0_0
#   pillow             pkgs/main/linux-64::pillow-8.2.0-py37he98fc37_0
#   pixman             pkgs/main/linux-64::pixman-0.40.0-h7b6447c_0
#   py-boost           pkgs/main/linux-64::py-boost-1.73.0-py37ha9443f7_11
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.1-pyhd3eb1b0_0
#   pytz               pkgs/main/noarch::pytz-2021.1-pyhd3eb1b0_0
#   rdkit              rdkit/linux-64::rdkit-2020.09.1.0-py37hd50e099_1
#   zstd               pkgs/main/linux-64::zstd-1.4.9-haebb681_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2021.5.25-h06a4308_1
#   certifi                                 2019.11.28-py37_0 --> 2021.5.30-py37h06a4308_0
#   conda                                        4.8.2-py37_0 --> 4.10.1-py37h06a4308_1
#   libffi                                   3.2.1-hd88cf55_4 --> 3.3-he6710b0_2
#   openssl                                 1.1.1d-h7b6447c_4 --> 1.1.1k-h27cfd23_0
#   xz                                       5.2.4-h14c3975_4 --> 5.2.5-h7b6447c_0
#
#
#
# Downloading and Extracting Packages
# xz-5.2.5             | 341 KB    | : 100% 1.0/1 [00:00<00:00, 11.06it/s]
# mkl-2021.2.0         | 144.3 MB  | : 100% 1.0/1 [00:06<00:00,  6.64s/it]
# freetype-2.10.4      | 596 KB    | : 100% 1.0/1 [00:00<00:00, 13.07it/s]
# numpy-1.20.2         | 23 KB     | : 100% 1.0/1 [00:00<00:00, 18.25it/s]
# olefile-0.46         | 50 KB     | : 100% 1.0/1 [00:00<00:00, 17.98it/s]
# jpeg-9b              | 214 KB    | : 100% 1.0/1 [00:00<00:00, 19.09it/s]
# libuuid-1.0.3        | 15 KB     | : 100% 1.0/1 [00:00<00:00, 14.28it/s]
# glib-2.68.2          | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  5.41it/s]
# rdkit-2020.09.1.0    | 25.8 MB   | : 100% 1.0/1 [00:05<00:00,  5.95s/it]
# certifi-2021.5.30    | 139 KB    | : 100% 1.0/1 [00:00<00:00, 19.29it/s]
# bzip2-1.0.8          | 78 KB     | : 100% 1.0/1 [00:00<00:00, 20.20it/s]
# mkl_fft-1.3.0        | 170 KB    | : 100% 1.0/1 [00:00<00:00, 20.28it/s]
# py-boost-1.73.0      | 204 KB    | : 100% 1.0/1 [00:00<00:00, 16.29it/s]
# pcre-8.44            | 212 KB    | : 100% 1.0/1 [00:00<00:00, 13.39it/s]
# fontconfig-2.13.1    | 250 KB    | : 100% 1.0/1 [00:00<00:00, 16.39it/s]
# pixman-0.40.0        | 370 KB    | : 100% 1.0/1 [00:00<00:00, 17.44it/s]
# pillow-8.2.0         | 622 KB    | : 100% 1.0/1 [00:00<00:00, 13.01it/s]
# lcms2-2.12           | 312 KB    | : 100% 1.0/1 [00:00<00:00, 17.47it/s]
# cairo-1.16.0         | 1.0 MB    | : 100% 1.0/1 [00:00<00:00, 10.84it/s]
# libwebp-base-1.2.0   | 437 KB    | : 100% 1.0/1 [00:00<00:00, 15.74it/s]
# mkl-service-2.3.0    | 55 KB     | : 100% 1.0/1 [00:00<00:00, 18.03it/s]
# ca-certificates-2021 | 112 KB    | : 100% 1.0/1 [00:00<00:00, 21.99it/s]
# mkl_random-1.2.1     | 287 KB    | : 100% 1.0/1 [00:00<00:00, 16.40it/s]
# python-dateutil-2.8. | 221 KB    | : 100% 1.0/1 [00:00<00:00, 15.30it/s]
# icu-58.2             | 10.5 MB   | : 100% 1.0/1 [00:00<00:00,  2.15it/s]
# pytz-2021.1          | 181 KB    | : 100% 1.0/1 [00:00<00:00,  6.66it/s]
# openssl-1.1.1k       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  6.00it/s]
# intel-openmp-2021.2. | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  9.74it/s]
# libxcb-1.14          | 505 KB    | : 100% 1.0/1 [00:00<00:00, 11.48it/s]
# libboost-1.73.0      | 13.9 MB   | : 100% 1.0/1 [00:02<00:00,  1.36s/it]
# libffi-3.3           | 50 KB     | : 100% 1.0/1 [00:00<00:00, 15.11it/s]
# libxml2-2.9.10       | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  9.18it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00, 18.64it/s]
# lz4-c-1.9.3          | 186 KB    | : 100% 1.0/1 [00:00<00:00, 18.51it/s]
# libtiff-4.2.0        | 502 KB    | : 100% 1.0/1 [00:00<00:00, 17.08it/s]
# zstd-1.4.9           | 480 KB    | : 100% 1.0/1 [00:00<00:00, 16.06it/s]
# numpy-base-1.20.2    | 4.5 MB    | : 100% 1.0/1 [00:00<00:00,  3.24it/s]
# libpng-1.6.37        | 278 KB    | : 100% 1.0/1 [00:00<00:00, 17.47it/s]
# pandas-1.2.4         | 8.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.61it/s]
# conda-4.10.1         | 2.9 MB    | : 100% 1.0/1 [00:00<00:00,  4.28it/s]
# done
# done
# done

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(df2.canonical_smiles)
df_lipinski
# Out:
#           MW     LogP  NumHDonors  NumHAcceptors
# 0    281.271  1.89262         0.0            5.0
# 1    415.589  3.81320         0.0            2.0
# 2    421.190  2.66050         0.0            4.0
# 3    293.347  3.63080         0.0            3.0
# 4    338.344  3.53900         0.0            5.0
# ..       ...      ...         ...            ...
# 128  338.359  3.40102         0.0            5.0
# 129  296.366  3.44330         0.0            3.0
# 130  276.291  4.09564         0.0            3.0
# 131  278.307  3.29102         0.0            3.0
# 132  282.383  4.10530         0.0            2.0
#
# [133 rows x 4 columns]

# %%
df3
# Out:
#     molecule_chembl_id  ...         class
# 0         CHEMBL187579  ...  intermediate
# 1         CHEMBL188487  ...  intermediate
# 2         CHEMBL185698  ...        active
# 3         CHEMBL426082  ...        active
# 4         CHEMBL187717  ...  intermediate
# ..                 ...  ...           ...
# 128      CHEMBL2146517  ...        active
# 129       CHEMBL187460  ...        active
# 130       CHEMBL363535  ...        active
# 131       CHEMBL227075  ...        active
# 132        CHEMBL45830  ...        active
#
# [133 rows x 4 columns]

# %%
df_combined = pd.concat([df3, df_lipinski], axis =1)
df_combined
# Out:
#     molecule_chembl_id  ... NumHAcceptors
# 0         CHEMBL187579  ...           5.0
# 1         CHEMBL188487  ...           2.0
# 2         CHEMBL185698  ...           4.0
# 3         CHEMBL426082  ...           3.0
# 4         CHEMBL187717  ...           5.0
# ..                 ...  ...           ...
# 128      CHEMBL2146517  ...           5.0
# 129       CHEMBL187460  ...           3.0
# 130       CHEMBL363535  ...           3.0
# 131       CHEMBL227075  ...           3.0
# 132        CHEMBL45830  ...           2.0
#
# [133 rows x 8 columns]

# %%
import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = float(i)*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', 1)
        
    return x

# %%
df_combined.standard_value.describe()
# Out:
# count          133
# unique          96
# top       200000.0
# freq             5
# Name: standard_value, dtype: object

# %%
-np.log10( (10**-9)* 100000000 )
# Out:
# 1.0

# %%
-np.log10( (10**-9)* 10000000000 )
# Out:
# -1.0

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if float(i) > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', 1)
        
    return x

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
#     molecule_chembl_id  ... standard_value_norm
# 0         CHEMBL187579  ...              7200.0
# 1         CHEMBL188487  ...              9400.0
# 2         CHEMBL185698  ...             13500.0
# 3         CHEMBL426082  ...             13110.0
# 4         CHEMBL187717  ...              2000.0
# ..                 ...  ...                 ...
# 128      CHEMBL2146517  ...             10600.0
# 129       CHEMBL187460  ...             10100.0
# 130       CHEMBL363535  ...             11500.0
# 131       CHEMBL227075  ...             10700.0
# 132        CHEMBL45830  ...             78900.0
#
# [133 rows x 8 columns]

# %%
df_final = pIC50(df_norm)
df_final
# Out:
#     molecule_chembl_id  ...     pIC50
# 0         CHEMBL187579  ...  5.142668
# 1         CHEMBL188487  ...  5.026872
# 2         CHEMBL185698  ...  4.869666
# 3         CHEMBL426082  ...  4.882397
# 4         CHEMBL187717  ...  5.698970
# ..                 ...  ...       ...
# 128      CHEMBL2146517  ...  4.974694
# 129       CHEMBL187460  ...  4.995679
# 130       CHEMBL363535  ...  4.939302
# 131       CHEMBL227075  ...  4.970616
# 132        CHEMBL45830  ...  4.102923
#
# [133 rows x 8 columns]

# %%
df_2class = df_final[df_final['class'] != 'intermediate']
df_2class
# Out:
#     molecule_chembl_id  ...     pIC50
# 2         CHEMBL185698  ...  4.869666
# 3         CHEMBL426082  ...  4.882397
# 5         CHEMBL365134  ...  6.008774
# 7         CHEMBL190743  ...  6.022276
# 8         CHEMBL365469  ...  4.950782
# ..                 ...  ...       ...
# 128      CHEMBL2146517  ...  4.974694
# 129       CHEMBL187460  ...  4.995679
# 130       CHEMBL363535  ...  4.939302
# 131       CHEMBL227075  ...  4.970616
# 132        CHEMBL45830  ...  4.102923
#
# [117 rows x 8 columns]

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='class', data=df_2class, edgecolor='black')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'pIC50', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

plt.savefig('plot_ic50.pdf')

# %%
def mannwhitney(descriptor, verbose=False):
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'class']
  df = df_2class[selection]
  active = df[df['class'] == 'active']
  active = active[descriptor]

  selection = [descriptor, 'class']
  df = df_2class[selection]
  inactive = df[df['class'] == 'inactive']
  inactive = inactive[descriptor]

# compare samples
  stat, p = mannwhitneyu(active, inactive)
  #print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'
  
  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney('pIC50')
# Out:
#   Descriptor  Statistics  ...  alpha                      Interpretation
# 0      pIC50         0.0  ...   0.05  Different distribution (reject H0)
#
# [1 rows x 5 columns]

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'MW', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

plt.savefig('plot_MW.pdf')

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics         p  alpha                      Interpretation
# 0         MW       404.5  0.001666   0.05  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'LogP', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

plt.savefig('plot_LogP.pdf')

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics  ...  alpha                         Interpretation
# 0       LogP       705.5  ...   0.05  Same distribution (fail to reject H0)
#
# [1 rows x 5 columns]

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHDonors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHDonors.pdf')

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics        p  alpha                      Interpretation
# 0  NumHDonors       298.5  0.00003   0.05  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHAcceptors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHAcceptors.pdf')

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics  ...  alpha                      Interpretation
# 0  NumHAcceptors       412.5  ...   0.05  Different distribution (reject H0)
#
# [1 rows x 5 columns]

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2021-06-10 04:51:17--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2021-06-10 04:51:17--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M   159MB/s    in 0.2s
#
# 2021-06-10 04:51:17 (159 MB/s) - ‘padel.zip’ saved [25768637/25768637]
#
# --2021-06-10 04:51:17--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh [following]
# --2021-06-10 04:51:17--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231 [text/plain]
# Saving to: ‘padel.sh’
#
# padel.sh            100%[===================>]     231  --.-KB/s    in 0s
#
# 2021-06-10 04:51:17 (9.90 MB/s) - ‘padel.sh’ saved [231/231]

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
#   inflating: __MACOSX/PaDEL-Descriptor/._config
#   inflating: PaDEL-Descriptor/PubchemFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._PubchemFingerprinter.xml
#   inflating: PaDEL-Descriptor/ExtendedFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._ExtendedFingerprinter.xml
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprinter.xml
#   inflating: PaDEL-Descriptor/GraphOnlyFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._GraphOnlyFingerprinter.xml
#   inflating: PaDEL-Descriptor/SubstructureFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprinter.xml
#   inflating: PaDEL-Descriptor/Descriptors.xls
#   inflating: __MACOSX/PaDEL-Descriptor/._Descriptors.xls
#    creating: PaDEL-Descriptor/lib/
#   inflating: __MACOSX/PaDEL-Descriptor/._lib
#   inflating: PaDEL-Descriptor/PaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/._PaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/SubstructureFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprintCount.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprintCount.xml
#   inflating: PaDEL-Descriptor/descriptors.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._descriptors.xml
#   inflating: PaDEL-Descriptor/license/lgpl-2.1.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl-2.1.txt
#   inflating: PaDEL-Descriptor/license/LICENSE.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._LICENSE.txt
#   inflating: PaDEL-Descriptor/license/README - CDK
#   inflating: __MACOSX/PaDEL-Descriptor/license/._README - CDK
#   inflating: PaDEL-Descriptor/license/lgpl.license
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl.license
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL.jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(4).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(2).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1(1).jar
#   inflating: PaDEL-Descriptor/lib/swing-worker-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._swing-worker-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(3).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(5).jar
#   inflating: PaDEL-Descriptor/lib/jama(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(1).jar
#   inflating: PaDEL-Descriptor/lib/appframework-1.0.3.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._appframework-1.0.3.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(7).jar
#   inflating: PaDEL-Descriptor/lib/vecmath1.2-1.14.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._vecmath1.2-1.14.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(6).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(2).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(4).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(5).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(2).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(3).jar
#   inflating: PaDEL-Descriptor/lib/jama(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(7).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(1).jar
#   inflating: PaDEL-Descriptor/lib/jama(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(3).jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all(1).jar
#   inflating: PaDEL-Descriptor/lib/jama.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama.jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all.jar
#   inflating: PaDEL-Descriptor/lib/jama(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(5).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(7).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(4).jar
#   inflating: PaDEL-Descriptor/lib/cdk-1.4.15.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._cdk-1.4.15.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(6).jar
#   inflating: PaDEL-Descriptor/lib/jama(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(1).jar
#   inflating: PaDEL-Descriptor/lib/guava-17.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._guava-17.0.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(5).jar

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df_final_selection = df_final[selection]
df_final_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21	CHEMBL187579
# O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21	CHEMBL188487
# O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21	CHEMBL185698
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21	CHEMBL426082
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]	CHEMBL187717

# %%
! cat molecule.smi | wc -l
# Out:
# 133

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL187579 in molecule.smi (1/133).
# Processing CHEMBL188487 in molecule.smi (2/133).
# Processing CHEMBL185698 in molecule.smi (3/133). Average speed: 2.17 s/mol.
# Processing CHEMBL187717 in molecule.smi (5/133). Average speed: 0.92 s/mol.
# Processing CHEMBL426082 in molecule.smi (4/133). Average speed: 1.13 s/mol.
# Processing CHEMBL365134 in molecule.smi (6/133). Average speed: 0.77 s/mol.
# Processing CHEMBL187598 in molecule.smi (7/133). Average speed: 0.70 s/mol.
# Processing CHEMBL190743 in molecule.smi (8/133). Average speed: 0.63 s/mol.
# Processing CHEMBL365469 in molecule.smi (9/133). Average speed: 0.61 s/mol.
# Processing CHEMBL188983 in molecule.smi (10/133). Average speed: 0.56 s/mol.
# Processing CHEMBL191575 in molecule.smi (11/133). Average speed: 0.54 s/mol.
# Processing CHEMBL370923 in molecule.smi (12/133). Average speed: 0.52 s/mol.
# Processing CHEMBL194398 in molecule.smi (13/133). Average speed: 0.55 s/mol.
# Processing CHEMBL196635 in molecule.smi (14/133). Average speed: 0.47 s/mol.
# Processing CHEMBL209287 in molecule.smi (15/133). Average speed: 0.48 s/mol.
# Processing CHEMBL358279 in molecule.smi (16/133). Average speed: 0.46 s/mol.
# Processing CHEMBL348660 in molecule.smi (17/133). Average speed: 0.46 s/mol.
# Processing CHEMBL379727 in molecule.smi (18/133). Average speed: 0.43 s/mol.
# Processing CHEMBL210525 in molecule.smi (19/133). Average speed: 0.41 s/mol.
# Processing CHEMBL148483 in molecule.smi (20/133). Average speed: 0.40 s/mol.
# Processing CHEMBL383725 in molecule.smi (21/133). Average speed: 0.38 s/mol.
# Processing CHEMBL118596 in molecule.smi (22/133). Average speed: 0.37 s/mol.
# Processing CHEMBL208732 in molecule.smi (23/133). Average speed: 0.37 s/mol.
# Processing CHEMBL208732 in molecule.smi (24/133). Average speed: 0.38 s/mol.
# Processing CHEMBL210146 in molecule.smi (25/133). Average speed: 0.37 s/mol.
# Processing CHEMBL210146 in molecule.smi (26/133). Average speed: 0.36 s/mol.
# Processing CHEMBL207458 in molecule.smi (27/133). Average speed: 0.36 s/mol.
# Processing CHEMBL207458 in molecule.smi (28/133). Average speed: 0.35 s/mol.
# Processing CHEMBL207484 in molecule.smi (29/133). Average speed: 0.34 s/mol.
# Processing CHEMBL207484 in molecule.smi (30/133). Average speed: 0.34 s/mol.
# Processing CHEMBL207207 in molecule.smi (31/133). Average speed: 0.33 s/mol.
# Processing CHEMBL207207 in molecule.smi (32/133). Average speed: 0.33 s/mol.
# Processing CHEMBL210487 in molecule.smi (33/133). Average speed: 0.33 s/mol.
# Processing CHEMBL210487 in molecule.smi (34/133). Average speed: 0.32 s/mol.
# Processing CHEMBL380470 in molecule.smi (35/133). Average speed: 0.33 s/mol.
# Processing CHEMBL380470 in molecule.smi (36/133). Average speed: 0.32 s/mol.
# Processing CHEMBL210612 in molecule.smi (37/133). Average speed: 0.32 s/mol.
# Processing CHEMBL210612 in molecule.smi (38/133). Average speed: 0.32 s/mol.
# Processing CHEMBL209667 in molecule.smi (39/133). Average speed: 0.32 s/mol.
# Processing CHEMBL210097 in molecule.smi (41/133). Average speed: 0.32 s/mol.
# Processing CHEMBL209667 in molecule.smi (40/133). Average speed: 0.31 s/mol.
# Processing CHEMBL378674 in molecule.smi (43/133). Average speed: 0.32 s/mol.
# Processing CHEMBL210097 in molecule.smi (42/133). Average speed: 0.31 s/mol.
# Processing CHEMBL378674 in molecule.smi (44/133). Average speed: 0.32 s/mol.
# Processing CHEMBL210216 in molecule.smi (45/133). Average speed: 0.32 s/mol.
# Processing CHEMBL210195 in molecule.smi (47/133). Average speed: 0.31 s/mol.
# Processing CHEMBL210216 in molecule.smi (46/133). Average speed: 0.32 s/mol.
# Processing CHEMBL210195 in molecule.smi (48/133). Average speed: 0.31 s/mol.
# Processing CHEMBL210437 in molecule.smi (49/133). Average speed: 0.31 s/mol.
# Processing CHEMBL378677 in molecule.smi (51/133). Average speed: 0.31 s/mol.
# Processing CHEMBL210437 in molecule.smi (50/133). Average speed: 0.30 s/mol.
# Processing CHEMBL378677 in molecule.smi (52/133). Average speed: 0.31 s/mol.
# Processing CHEMBL210972 in molecule.smi (53/133). Average speed: 0.31 s/mol.
# Processing CHEMBL210972 in molecule.smi (54/133). Average speed: 0.30 s/mol.
# Processing CHEMBL210145 in molecule.smi (56/133). Average speed: 0.30 s/mol.
# Processing CHEMBL210145 in molecule.smi (55/133). Average speed: 0.30 s/mol.
# Processing CHEMBL377225 in molecule.smi (58/133). Average speed: 0.29 s/mol.
# Processing CHEMBL377225 in molecule.smi (57/133). Average speed: 0.30 s/mol.
# Processing CHEMBL210823 in molecule.smi (59/133). Average speed: 0.30 s/mol.
# Processing CHEMBL210823 in molecule.smi (60/133). Average speed: 0.29 s/mol.
# Processing CHEMBL207381 in molecule.smi (61/133). Average speed: 0.30 s/mol.
# Processing CHEMBL207381 in molecule.smi (62/133). Average speed: 0.29 s/mol.
# Processing CHEMBL210511 in molecule.smi (63/133). Average speed: 0.30 s/mol.
# Processing CHEMBL210511 in molecule.smi (64/133). Average speed: 0.30 s/mol.
# Processing CHEMBL210632 in molecule.smi (65/133). Average speed: 0.30 s/mol.
# Processing CHEMBL210632 in molecule.smi (66/133). Average speed: 0.29 s/mol.
# Processing CHEMBL210497 in molecule.smi (67/133). Average speed: 0.30 s/mol.
# Processing CHEMBL210497 in molecule.smi (68/133). Average speed: 0.29 s/mol.
# Processing CHEMBL208584 in molecule.smi (69/133). Average speed: 0.30 s/mol.
# Processing CHEMBL208584 in molecule.smi (70/133). Average speed: 0.29 s/mol.
# Processing CHEMBL208763 in molecule.smi (71/133). Average speed: 0.29 s/mol.
# Processing CHEMBL208763 in molecule.smi (72/133). Average speed: 0.29 s/mol.
# Processing CHEMBL209227 in molecule.smi (73/133). Average speed: 0.29 s/mol.
# Processing CHEMBL209227 in molecule.smi (74/133). Average speed: 0.29 s/mol.
# Processing CHEMBL210092 in molecule.smi (75/133). Average speed: 0.29 s/mol.
# Processing CHEMBL210092 in molecule.smi (76/133). Average speed: 0.29 s/mol.
# Processing CHEMBL377150 in molecule.smi (77/133). Average speed: 0.29 s/mol.
# Processing CHEMBL377150 in molecule.smi (78/133). Average speed: 0.29 s/mol.
# Processing CHEMBL212454 in molecule.smi (79/133). Average speed: 0.29 s/mol.
# Processing CHEMBL213581 in molecule.smi (80/133). Average speed: 0.28 s/mol.
# Processing CHEMBL380403 in molecule.smi (81/133). Average speed: 0.28 s/mol.
# Processing CHEMBL212504 in molecule.smi (82/133). Average speed: 0.28 s/mol.
# Processing CHEMBL211969 in molecule.smi (83/133). Average speed: 0.28 s/mol.
# Processing CHEMBL384739 in molecule.smi (84/133). Average speed: 0.28 s/mol.
# Processing CHEMBL212240 in molecule.smi (86/133). Average speed: 0.28 s/mol.
# Processing CHEMBL215732 in molecule.smi (85/133). Average speed: 0.28 s/mol.
# Processing CHEMBL377253 in molecule.smi (87/133). Average speed: 0.27 s/mol.
# Processing CHEMBL215397 in molecule.smi (88/133). Average speed: 0.27 s/mol.
# Processing CHEMBL378342 in molecule.smi (89/133). Average speed: 0.27 s/mol.
# Processing CHEMBL379642 in molecule.smi (90/133). Average speed: 0.27 s/mol.
# Processing CHEMBL427404 in molecule.smi (91/133). Average speed: 0.27 s/mol.
# Processing CHEMBL212190 in molecule.smi (92/133). Average speed: 0.27 s/mol.
# Processing CHEMBL378700 in molecule.smi (93/133). Average speed: 0.26 s/mol.
# Processing CHEMBL212019 in molecule.smi (94/133). Average speed: 0.26 s/mol.
# Processing CHEMBL212399 in molecule.smi (95/133). Average speed: 0.26 s/mol.
# Processing CHEMBL215733 in molecule.smi (96/133). Average speed: 0.26 s/mol.
# Processing CHEMBL375130 in molecule.smi (97/133). Average speed: 0.26 s/mol.
# Processing CHEMBL214372 in molecule.smi (98/133). Average speed: 0.26 s/mol.
# Processing CHEMBL212218 in molecule.smi (99/133). Average speed: 0.26 s/mol.
# Processing CHEMBL222840 in molecule.smi (100/133). Average speed: 0.25 s/mol.
# Processing CHEMBL222735 in molecule.smi (102/133). Average speed: 0.25 s/mol.
# Processing CHEMBL222769 in molecule.smi (101/133). Average speed: 0.25 s/mol.
# Processing CHEMBL222628 in molecule.smi (103/133). Average speed: 0.25 s/mol.
# Processing CHEMBL222893 in molecule.smi (104/133). Average speed: 0.25 s/mol.
# Processing CHEMBL222234 in molecule.smi (106/133). Average speed: 0.25 s/mol.
# Processing CHEMBL225515 in molecule.smi (105/133). Average speed: 0.25 s/mol.
# Processing CHEMBL187266 in molecule.smi (108/133). Average speed: 0.24 s/mol.
# Processing CHEMBL426898 in molecule.smi (107/133). Average speed: 0.24 s/mol.
# Processing CHEMBL215254 in molecule.smi (109/133). Average speed: 0.24 s/mol.
# Processing CHEMBL2146517 in molecule.smi (110/133). Average speed: 0.24 s/mol.
# Processing CHEMBL187460 in molecule.smi (111/133). Average speed: 0.24 s/mol.
# Processing CHEMBL363535 in molecule.smi (112/133). Average speed: 0.24 s/mol.
# Processing CHEMBL227075 in molecule.smi (113/133). Average speed: 0.24 s/mol.
# Processing CHEMBL187266 in molecule.smi (115/133). Average speed: 0.24 s/mol.
# Processing CHEMBL45830 in molecule.smi (114/133). Average speed: 0.24 s/mol.
# Processing CHEMBL215254 in molecule.smi (116/133). Average speed: 0.24 s/mol.
# Processing CHEMBL2146517 in molecule.smi (117/133). Average speed: 0.24 s/mol.
# Processing CHEMBL187460 in molecule.smi (118/133). Average speed: 0.24 s/mol.
# Processing CHEMBL363535 in molecule.smi (119/133). Average speed: 0.24 s/mol.
# Processing CHEMBL227075 in molecule.smi (120/133). Average speed: 0.24 s/mol.
# Processing CHEMBL45830 in molecule.smi (121/133). Average speed: 0.24 s/mol.
# Processing CHEMBL215254 in molecule.smi (122/133). Average speed: 0.24 s/mol.
# Processing CHEMBL187460 in molecule.smi (123/133). Average speed: 0.24 s/mol.
# Processing CHEMBL227075 in molecule.smi (125/133). Average speed: 0.24 s/mol.
# Processing CHEMBL363535 in molecule.smi (124/133). Average speed: 0.24 s/mol.
# Processing CHEMBL45830 in molecule.smi (126/133). Average speed: 0.24 s/mol.
# Processing CHEMBL215254 in molecule.smi (128/133). Average speed: 0.24 s/mol.
# Processing CHEMBL187266 in molecule.smi (127/133). Average speed: 0.24 s/mol.
# Processing CHEMBL2146517 in molecule.smi (129/133). Average speed: 0.24 s/mol.
# Processing CHEMBL187460 in molecule.smi (130/133). Average speed: 0.25 s/mol.
# Processing CHEMBL363535 in molecule.smi (131/133). Average speed: 0.25 s/mol.
# Processing CHEMBL227075 in molecule.smi (132/133). Average speed: 0.24 s/mol.
# Processing CHEMBL45830 in molecule.smi (133/133). Average speed: 0.25 s/mol.
# Descriptor calculation completed in 32.483 secs . Average speed: 0.24 s/mol.

# %%
! ls -l
# Out:
# total 108640
# -rw-r--r-- 1 root root   247688 Jun 10 04:51 descriptors_output.csv
# drwxr-xr-x 3 root root     4096 Jun 10 04:51 __MACOSX
# -rw-r--r-- 1 root root      121 Jun 10 04:51 mannwhitneyu_LogP.csv
# -rw-r--r-- 1 root root      119 Jun 10 04:51 mannwhitneyu_MW.csv
# -rw-r--r-- 1 root root      130 Jun 10 04:51 mannwhitneyu_NumHAcceptors.csv
# -rw-r--r-- 1 root root      128 Jun 10 04:51 mannwhitneyu_NumHDonors.csv
# -rw-r--r-- 1 root root      121 Jun 10 04:51 mannwhitneyu_pIC50.csv
# -rwxr-xr-x 1 root root 85055499 Mar 11  2020 Miniconda3-py37_4.8.2-Linux-x86_64.sh
# -rw-r--r-- 1 root root     7991 Jun 10 04:51 molecule.smi
# drwxrwxr-x 4 root root     4096 May 30  2020 PaDEL-Descriptor
# -rw-r--r-- 1 root root      231 Jun 10 04:51 padel.sh
# -rw-r--r-- 1 root root 25768637 Jun 10 04:51 padel.zip
# -rw-r--r-- 1 root root    14698 Jun 10 04:51 plot_ic50.pdf
# -rw-r--r-- 1 root root    14066 Jun 10 04:51 plot_LogP.pdf
# -rw-r--r-- 1 root root    12969 Jun 10 04:51 plot_MW.pdf
# -rw-r--r-- 1 root root    33982 Jun 10 04:51 plot_MW_vs_LogP.pdf
# -rw-r--r-- 1 root root    14568 Jun 10 04:51 plot_NumHAcceptors.pdf
# -rw-r--r-- 1 root root    14058 Jun 10 04:51 plot_NumHDonors.pdf
# drwxr-xr-x 1 root root     4096 Jun  1 13:40 sample_data

# %%
df3_X = pd.read_csv('descriptors_output.csv')
df3_X
# Out:
#               Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0     CHEMBL187579           1  ...             0             0
# 1     CHEMBL188487           1  ...             0             0
# 2     CHEMBL185698           1  ...             0             0
# 3     CHEMBL426082           1  ...             0             0
# 4     CHEMBL187717           1  ...             0             0
# ..             ...         ...  ...           ...           ...
# 128   CHEMBL187460           1  ...             0             0
# 129  CHEMBL2146517           1  ...             0             0
# 130   CHEMBL227075           1  ...             0             0
# 131   CHEMBL363535           1  ...             0             0
# 132    CHEMBL45830           1  ...             0             0
#
# [133 rows x 882 columns]

# %%
df3_X = df3_X.drop(columns=['Name'])
df3_X
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 128           1           1  ...             0             0
# 129           1           1  ...             0             0
# 130           1           1  ...             0             0
# 131           1           1  ...             0             0
# 132           1           1  ...             0             0
#
# [133 rows x 881 columns]

# %%
df3_Y = df_final['pIC50']
df3_Y
# Out:
# 0      5.142668
# 1      5.026872
# 2      4.869666
# 3      4.882397
# 4      5.698970
#          ...
# 128    4.974694
# 129    4.995679
# 130    4.939302
# 131    4.970616
# 132    4.102923
# Name: pIC50, Length: 133, dtype: float64

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3
# Out:
#      PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0             1           1           0  ...             0             0  5.142668
# 1             1           1           0  ...             0             0  5.026872
# 2             1           1           0  ...             0             0  4.869666
# 3             1           1           0  ...             0             0  4.882397
# 4             1           1           0  ...             0             0  5.698970
# ..          ...         ...         ...  ...           ...           ...       ...
# 128           1           1           1  ...             0             0  4.974694
# 129           1           1           1  ...             0             0  4.995679
# 130           1           1           0  ...             0             0  4.939302
# 131           1           1           0  ...             0             0  4.970616
# 132           1           1           1  ...             0             0  4.102923
#
# [133 rows x 882 columns]

# %%
dataset3.to_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv', index=False)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
X = dataset3.drop('pIC50', axis=1)
X
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 128           1           1  ...             0             0
# 129           1           1  ...             0             0
# 130           1           1  ...             0             0
# 131           1           1  ...             0             0
# 132           1           1  ...             0             0
#
# [133 rows x 881 columns]

# %%
Y = dataset3.pIC50
Y
# Out:
# 0      5.142668
# 1      5.026872
# 2      4.869666
# 3      4.882397
# 4      5.698970
#          ...
# 128    4.974694
# 129    4.995679
# 130    4.939302
# 131    4.970616
# 132    4.102923
# Name: pIC50, Length: 133, dtype: float64

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((106, 200), (106,))

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2 = model.score(X_test, Y_test)
r2
# Out:
# 0.041659835635650566

# %%
Y_pred = model.predict(X_test)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(Y_test, Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.show>

# %%
df_final
# Out:
#     molecule_chembl_id  ...     pIC50
# 0         CHEMBL187579  ...  5.142668
# 1         CHEMBL188487  ...  5.026872
# 2         CHEMBL185698  ...  4.869666
# 3         CHEMBL426082  ...  4.882397
# 4         CHEMBL187717  ...  5.698970
# ..                 ...  ...       ...
# 128      CHEMBL2146517  ...  4.974694
# 129       CHEMBL187460  ...  4.995679
# 130       CHEMBL363535  ...  4.939302
# 131       CHEMBL227075  ...  4.970616
# 132        CHEMBL45830  ...  4.102923
#
# [133 rows x 8 columns]

# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.9-py2.py3-none-any.whl (12 kB)
# Collecting scipy==1.5.4
#   Downloading scipy-1.5.4-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 63.1 MB/s
# Collecting xgboost==1.1.1
#   Downloading xgboost-1.1.1-py3-none-manylinux2010_x86_64.whl (127.6 MB)
#      |████████████████████████████████| 127.6 MB 8.6 kB/s
# Collecting tqdm==4.56.0
#   Downloading tqdm-4.56.0-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 952 kB/s
# Collecting pandas==1.0.5
#   Downloading pandas-1.0.5-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 24.7 MB/s
# Collecting numpy==1.19.1
#   Downloading numpy-1.19.1-cp37-cp37m-manylinux2010_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 10 kB/s
# Collecting PyYAML==5.3.1
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
#      |████████████████████████████████| 269 kB 43.2 MB/s
# Collecting scikit-learn==0.23.1
#   Downloading scikit_learn-0.23.1-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 22.7 MB/s
# Collecting lightgbm==2.3.1
#   Downloading lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 39.9 MB/s
# Collecting joblib==1.0.0
#   Downloading joblib-1.0.0-py3-none-any.whl (302 kB)
#      |████████████████████████████████| 302 kB 58.4 MB/s
# Collecting pytest==5.4.3
#   Downloading pytest-5.4.3-py3-none-any.whl (248 kB)
#      |████████████████████████████████| 248 kB 67.6 MB/s
# Collecting click==7.1.2
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 1.0 MB/s
# Collecting six==1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/site-packages (from pandas==1.0.5->lazypredict) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/site-packages (from pandas==1.0.5->lazypredict) (2021.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting pluggy<1.0,>=0.12
#   Downloading pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Collecting py>=1.5.0
#   Downloading py-1.10.0-py2.py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 6.1 MB/s
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting more-itertools>=4.0.0
#   Downloading more_itertools-8.8.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 4.9 MB/s
# Collecting importlib-metadata>=0.12; python_version < "3.8"
#   Downloading importlib_metadata-4.5.0-py3-none-any.whl (17 kB)
# Collecting packaging
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.1 MB/s
# Collecting attrs>=17.4.0
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.0 MB/s
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 5.0 MB/s
# Building wheels for collected packages: PyYAML
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=393706 sha256=4c4a080eddf4359c93ead7785952c0083d603ed224461fb15797c7ae41589c3c
#   Stored in directory: /root/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
# Successfully built PyYAML
# Installing collected packages: numpy, scipy, xgboost, tqdm, pandas, PyYAML, joblib, threadpoolctl, scikit-learn, lightgbm, zipp, typing-extensions, importlib-metadata, pluggy, py, wcwidth, more-itertools, pyparsing, packaging, attrs, pytest, click, six, lazypredict
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.2
#     Uninstalling numpy-1.20.2:
#       Successfully uninstalled numpy-1.20.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.42.1
#     Uninstalling tqdm-4.42.1:
#       Successfully uninstalled tqdm-4.42.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.4
#     Uninstalling pandas-1.2.4:
#       Successfully uninstalled pandas-1.2.4
#   Attempting uninstall: six
#     Found existing installation: six 1.14.0
#     Uninstalling six-1.14.0:
#       Successfully uninstalled six-1.14.0
# Successfully installed PyYAML-5.3.1 attrs-21.2.0 click-7.1.2 importlib-metadata-4.5.0 joblib-1.0.0 lazypredict-0.2.9 lightgbm-2.3.1 more-itertools-8.8.0 numpy-1.19.1 packaging-20.9 pandas-1.0.5 pluggy-0.13.1 py-1.10.0 pyparsing-2.4.7 pytest-5.4.3 scikit-learn-0.23.1 scipy-1.5.4 six-1.15.0 threadpoolctl-2.1.0 tqdm-4.56.0 typing-extensions-3.10.0.0 wcwidth-0.2.5 xgboost-1.1.1 zipp-3.4.1

# %%
import lazypredict
from lazypredict.Supervised import LazyRegressor
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
X = dataset3.drop('pIC50', axis=1)
X
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 128           1           1  ...             0             0
# 129           1           1  ...             0             0
# 130           1           1  ...             0             0
# 131           1           1  ...             0             0
# 132           1           1  ...             0             0
#
# [133 rows x 881 columns]

# %%
Y = dataset3.pIC50
Y
# Out:
# 0     5.14
# 1     5.03
# 2     4.87
# 3     4.88
# 4     5.70
#       ...
# 128   4.97
# 129   5.00
# 130   4.94
# 131   4.97
# 132   4.10
# Name: pIC50, Length: 133, dtype: float64

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
#  97%|█████████▋| 37/38 [00:12<00:00,  5.95it/s]
# [04:53:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 100%|██████████| 38/38 [00:12<00:00,  3.09it/s]
# 100%|██████████| 38/38 [00:00<00:00, 23528.72it/s]

# %%
predictions_train
# Out:
#                                                               Adjusted R-Squared  ...  Time Taken
# Model                                                                             ...
# Lars                          92063969317503272940437118251190912378167135750...  ...        0.26
# KernelRidge                                                                 7.39  ...        0.03
# LassoLars                                                                   2.11  ...        0.02
# LassoLarsIC                                                                 2.11  ...        0.04
# DummyRegressor                                                              2.11  ...        0.03
# Lasso                                                                       1.95  ...        0.03
# PassiveAggressiveRegressor                                                  1.86  ...        0.01
# ElasticNet                                                                  1.68  ...        0.04
# SVR                                                                         1.57  ...        0.02
# LarsCV                                                                      1.57  ...        0.70
# LassoLarsCV                                                                 1.52  ...        0.14
# OrthogonalMatchingPursuitCV                                                 1.52  ...        0.03
# NuSVR                                                                       1.48  ...        0.02
# LinearSVR                                                                   1.47  ...        0.10
# LassoCV                                                                     1.47  ...        3.80
# ElasticNetCV                                                                1.47  ...        4.74
# HuberRegressor                                                              1.46  ...        0.10
# KNeighborsRegressor                                                         1.45  ...        0.02
# BayesianRidge                                                               1.44  ...        0.06
# SGDRegressor                                                                1.41  ...        0.04
# AdaBoostRegressor                                                           1.39  ...        0.06
# HistGradientBoostingRegressor                                               1.39  ...        0.37
# LGBMRegressor                                                               1.39  ...        0.05
# BaggingRegressor                                                            1.37  ...        0.04
# OrthogonalMatchingPursuit                                                   1.37  ...        0.02
# RidgeCV                                                                     1.35  ...        0.04
# RandomForestRegressor                                                       1.34  ...        0.31
# XGBRegressor                                                                1.32  ...        0.17
# MLPRegressor                                                                1.32  ...        0.34
# GradientBoostingRegressor                                                   1.32  ...        0.15
# Ridge                                                                       1.32  ...        0.03
# LinearRegression                                                            1.31  ...        0.03
# TransformedTargetRegressor                                                  1.31  ...        0.02
# GaussianProcessRegressor                                                    1.31  ...        0.02
# ExtraTreesRegressor                                                         1.31  ...        0.29
# ExtraTreeRegressor                                                          1.31  ...        0.02
# DecisionTreeRegressor                                                       1.31  ...        0.04
#
# [37 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
